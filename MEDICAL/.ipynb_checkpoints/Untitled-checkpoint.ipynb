# %%
import os
import cv2
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, optimizers, models, callbacks
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2022-05-29 18:01:15.086350: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-29 18:01:15.086379: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
image_generator = ImageDataGenerator(rescale=1./255)

train_generator = image_generator.flow_from_directory(batch_size=40, directory="./Dataset", shuffle=True, 
                                                      target_size=(256, 256), class_mode="categorical", subset="training")
# Out:
# Found 532 images belonging to 4 classes.

# %%
train_images, train_labels = next(train_generator)
label_names = {0: "covid-19", 1: "Normal", 2: "viral pneumonia", 3: "bacterial pneumonia"}

# %%
fig, axes = plt.subplots(6, 6, figsize=(20, 20))
axes = axes.ravel()
for i in range(36):
    axes[i].imshow(train_images[i])
    axes[i].set_title(label_names[np.argmax(train_labels[i])])
    axes[i].axis("off")

# %%
base_model = ResNet50(weights="imagenet", include_top=False, input_tensor=layers.Input(shape=(256, 256, 3)))
# Out:
# 2022-05-29 18:01:57.872789: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:923] could not open file to read NUMA node: /sys/bus/pci/devices/0000:2b:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-05-29 18:01:57.872864: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-29 18:01:57.872893: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-05-29 18:01:57.872916: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# ...

# %%
base_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# ...

# %%
for layer in base_model.layers[:-10]:
    layers.trainable = False

# %%
head_model = base_model.output
head_model = layers.AveragePooling2D()(head_model)
head_model = layers.Flatten()(head_model)
head_model = layers.Dense(256, "relu")(head_model)
head_model = layers.Dropout(0.2)(head_model)
head_model = layers.Dense(256, "relu")(head_model)
head_model = layers.Dropout(0.2)(head_model)
head_model = layers.Dense(4, "softmax")(head_model)

model = models.Model(base_model.input, head_model)

model.compile(loss="categorical_crossentropy", optimizer=optimizers.RMSprop(lr=1e-4, decay=1e-6), metrics="acc")
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 128, 128, 64) 0           conv1_bn[0][0]
# ...

# %%
checkpointer = callbacks.ModelCheckpoint(filepath="./weights.hdf5")

# %%
#Não será separado o dataset de teste devido ao tamanho da base de dados
train_generator = image_generator.flow_from_directory(batch_size=4, directory="./Dataset", shuffle=True, 
                                                      target_size=(256, 256), class_mode="categorical", subset="training")
# Out:
# Found 532 images belonging to 4 classes.

# %%
history = model.fit(train_generator, epochs=50, callbacks=checkpointer)
# Out:
# 2022-05-29 18:03:53.745228: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 133/133 [==============================] - 78s 550ms/step - loss: 2.9989 - acc: 0.4380
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# Epoch 2/50
# 106/133 [======================>.......] - ETA: 14s - loss: 1.3836 - acc: 0.5519
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 history = model.fit(train_generator, epochs=50, callbacks=checkpointer)
#
# ...
